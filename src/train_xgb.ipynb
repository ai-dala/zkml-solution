# %%
import xgboost as xgb

# %%
import pandas as pd
import os

# Replace 'path_to_your_file.csv' with the actual path to your CSV file in Google Drive
current_dir = os.path.dirname(os.path.abspath(""))
file_path = os.path.join(current_dir, "src", "data", "merged_data.csv")
data = pd.read_csv(file_path)

data['Difficulty For Model'] = data['Difficulty'] / (10 ** 13)

# %%
x = data[["Electricity_day_price", 'Difficulty For Model', 'HashRate', 'Power', 'Block Reward', 'Cost_2_months', 'Cost_3_months', 'Cost_4_months', 'Cost_5_months', 'Cost_6_months']].values

# %%
y = data[['BTC_needed_2_months', 'BTC_needed_3_months', 'BTC_needed_4_months', 'BTC_needed_5_months', 'BTC_needed_6_months']].values

# %%
import xgboost as xgb
from sklearn.datasets import load_diabetes
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=42)

# %%
# Increase the number of trees and maximum depth
n_estimators = 1  # Increase the number of trees
max_depth = 10  # Increase the maximum depth of each tree

xgb_reg = xgb.XGBRegressor(
    n_estimators=n_estimators,
    max_depth=max_depth,
    )
xgb_reg.fit(X_train, y_train)
# Out:
# XGBRegressor(base_score=None, booster=None, callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=None, device=None, early_stopping_rounds=None,
#              enable_categorical=False, eval_metric=None, feature_types=None,
#              gamma=None, grow_policy=None, importance_type=None,
#              interaction_constraints=None, learning_rate=None, max_bin=None,
#              max_cat_threshold=None, max_cat_to_onehot=None,
#              max_delta_step=None, max_depth=2, max_leaves=None,
#              min_child_weight=None, missing=nan, monotone_constraints=None,
#              multi_strategy=None, n_estimators=2, n_jobs=None,
#              num_parallel_tree=None, random_state=None, ...)

# %%
preds = xgb_reg.predict(X_test)

print(preds)
# Out:
# [[0.03842793 0.04298466 0.04767507 0.04982734 0.05402622]
#  [0.0535007  0.06652202 0.07955848 0.08848547 0.10112534]
#  [0.03842793 0.04298466 0.04767507 0.04982734 0.05402622]
#  ...
#  [0.0535007  0.06652202 0.07955848 0.08848547 0.10112534]
#  [0.03842793 0.04298466 0.04767507 0.04982734 0.05402622]
#  [0.03842793 0.04298466 0.04767507 0.06532349 0.07286097]]

# %%
y_test
# Out:
# array([[0.0180677 , 0.02921145, 0.04867974, 0.0641998 , 0.09655696],
#        [0.02173457, 0.03194286, 0.05175498, 0.07386997, 0.10381171],
#        [0.01352346, 0.02005181, 0.02646079, 0.03160607, 0.03504033],
#        ...,
#        [0.02106291, 0.03383307, 0.05146417, 0.07252267, 0.09970991],
#        [0.02458877, 0.0344921 , 0.04044718, 0.04641207, 0.05086355],
#        [0.05692109, 0.08267231, 0.10638507, 0.12919926, 0.15593203]])

# %%
from giza.zkcook import serialize_model
serialize_model(xgb_reg, "xgb_aidala.json")
